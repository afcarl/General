# %%
#import plotly.plotly as py
#py.sign_in('username', 'api_key')
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from mpl_toolkits.mplot3d import Axes3D

# %%
sweden = pd.read_csv('sweden.csv')
bangladesh = pd.read_csv('bangladesh.csv')
niger = pd.read_csv('niger.csv')

# %%
bangladesh
# Out:
#    Country or Area  Year     Value  Value Footnotes
# 0       Bangladesh  2014       NaN              NaN
# 1       Bangladesh  2012       NaN              NaN
# 2       Bangladesh  2010  98.42540              NaN
# 3       Bangladesh  2009  99.47924              NaN
# 4       Bangladesh  2008  95.29395              NaN
# 5       Bangladesh  2007       NaN              NaN
# 6       Bangladesh  2006  99.63241              NaN
# 7       Bangladesh  2005  98.20926              NaN
# 8       Bangladesh  2004       NaN              NaN
# 9       Bangladesh  2002       NaN              NaN
# 10      Bangladesh  2001       NaN              NaN
# 11      Bangladesh  2000       NaN              NaN
# 12      Bangladesh  1998       NaN              NaN
# 13      Bangladesh  1997       NaN              NaN
# 14      Bangladesh  1996       NaN              NaN
# 15      Bangladesh  1995       NaN              NaN
# 16      Bangladesh  1994       NaN              NaN
# 17      Bangladesh  1993       NaN              NaN
# 18      Bangladesh  1992       NaN              NaN
# 19      Bangladesh  1991       NaN              NaN
# 20      Bangladesh  1990  66.29983              NaN

# %%
z = 5
print ([niger['Value'].iloc[z],bangladesh['Value'].iloc[z],sweden['Value'].iloc[z]])
# Out:
# [46.404119999999999, nan, 99.059629999999999]

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation
from mpl_toolkits.mplot3d import Axes3D

# Create some random data, I took this piece from here:
# http://matplotlib.org/mpl_examples/mplot3d/scatter3d_demo.py
def randrange(n, vmin, vmax):
    return (vmax - vmin) * np.random.rand(n) + vmin
n = 100
xx = randrange(n, 23, 32)
yy = randrange(n, 0, 100)
zz = randrange(n, -50, -25)

# Create a figure and a 3D Axes
fig = plt.figure()
ax = Axes3D(fig)

# Create an init function and the animate functions.
# Both are explained in the tutorial. Since we are changing
# the the elevation and azimuth and no objects are really
# changed on the plot we don't have to return anything from
# the init and animate function. (return value is explained
# in the tutorial.
def init():
    x = np.linspace(0, 100, 100)
    y = np.linspace(0, 100, 100)
    ax.scatter(xx, yy, zz, marker='o', s=20, c="goldenrod", alpha=0.6)

def animate(i):
    ax.view_init(elev=10., azim=i)

# Animate
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=360, interval=20, blit=True)
# Save
#anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig = plt.figure()
k = 2
ax = fig.add_subplot(111,projection='3d')
for c,z in zip(['r','g','b'],[2010,2009,2008]):
    ys = np.array([niger['Value'].iloc[k],bangladesh['Value'].iloc[k],sweden['Value'].iloc[k]])
    print ys
    xs = np.array([1,2,3])
    print xs
    cs = [c]*len(xs)
    print z
    print cs
    
    
    ax.bar(xs,ys,zs=z,zdir='y',color=cs,alpha=0.8)
    print 'bar'
    k = k+1
ax.set_xlabel('X') 
ax.set_ylabel('Y')    
ax.set_zlabel('Z')  
plt.show()
# Out:
# [ 57.87286  98.4254   99.27005]
# [1 2 3]
# 2010
# ['r', 'r', 'r']
# bar
# [ 55.6237   99.47924  99.23112]
# [1 2 3]
# 2009
# ['g', 'g', 'g']
# bar
# [ 50.6106   95.29395  99.07924]
# [1 2 3]
# 2008
# ['b', 'b', 'b']
# bar

# %%
from numpy import pi, cos, exp

# Define the function to be plotted
def fxy(x, y):
    A = 1  # choose a maximum amplitude 
    return A*(cos(pi*x*y))**2 * exp(-(x**2+y**2)/2.)

# Choose length of square domain, make row and column vectors
L = 4
x = y = np.arange(-L/2., L/2., 0.1)  # use a mesh spacing of 0.1
yt = y[:, np.newaxis]  # (!) make column vector

# Get surface coordinates!
z = fxy(x, yt)

trace1 = Surface(
    z=z,  # link the fxy 2d numpy array
    x=x,  # link 1d numpy array of x coords
    y=y   # link 1d numpy array of y coords
)

# Package the trace dictionary into a data object
data = Data([trace1])

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for c,z in zip(['r','g','b','y'],[30,20,10,0]):
    xs = np.arange(20)
    ys = np.random.rand(20)
    cs = [c]*len(xs)
    print cs
    cs[0]='c'
    print cs
    ax.bar(xs,ys,zs=z,zdir='y',color=cs,alpha=0.8)
    
ax.set_xlabel('X') 
ax.set_ylabel('Y')    
ax.set_zlabel('Z')  
plt.show()
